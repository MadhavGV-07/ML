# %% [markdown]
# <a href="https://colab.research.google.com/github/MadhavGV-07/ML/blob/main/AML_USING_GNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# !unzip -q "/content/drive/MyDrive/ML_PROJECT_full.zip" -d /content/ML_PROJECT
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip -o "/content/drive/MyDrive/ML_PROJECT_full.zip" -d /content/ML_PROJECT
# Out:
# Archive:  /content/drive/MyDrive/ML_PROJECT_full.zip
#   inflating: /content/ML_PROJECT/aml_generator.py
#   inflating: /content/ML_PROJECT/app.py
#   inflating: /content/ML_PROJECT/engine.py
#   inflating: /content/ML_PROJECT/gnn_models.py
#   inflating: /content/ML_PROJECT/requirements.txt
#   inflating: /content/ML_PROJECT/run.py
#   inflating: /content/ML_PROJECT/SAML-D.csv
#   inflating: /content/ML_PROJECT/test_aml_gnn.py
#   inflating: /content/ML_PROJECT/static/css/style.css
#   inflating: /content/ML_PROJECT/static/js/app.js
#   inflating: /content/ML_PROJECT/templates/index.html
#   inflating: /content/ML_PROJECT/uploads/current_upload.csv

# %%
# !ls -lh
# Out:
# total 12K
# drwx------ 5 root root 4.0K Sep 23 17:22 drive
# drwxr-xr-x 5 root root 4.0K Sep 23 17:39 ML_PROJECT
# drwxr-xr-x 1 root root 4.0K Sep 16 13:26 sample_data

# %%
# %cd /content/ML_PROJECT
# Out:
# /content/ML_PROJECT

# %%
# !pip install -r requirements.txt

# %%
import subprocess
import time
import re

# %%
# !wget -q -nc https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i cloudflared-linux-amd64.deb > /dev/null 2>&1

# %%
tunnel = subprocess.Popen(
    ["cloudflared", "tunnel", "--url", "http://127.0.0.1:5000"],
    stdout=subprocess.PIPE,
    stderr=subprocess.PIPE,
    text=True
)

# %%
public_url = None
time.sleep(3)
for _ in range(15):
    line = tunnel.stderr.readline()
    match = re.search(r'https://[a-zA-Z0-9-]+\.trycloudflare\.com', line)
    if match:
        public_url = match.group(0)
        break
    time.sleep(0.5)

# %%
print("\n" + "=" * 60)
print(f"🚀 SPECTRA AML DASHBOARD IS LIVE AT:\n👉 {public_url}")
print("=" * 60 + "\n")
# Out:
# ...
# 🚀 SPECTRA AML DASHBOARD IS LIVE AT:
# 👉 https://shorts-create-encourages-sequences.trycloudflare.com
# ...

# %%
# !python -c "from app import app; app.run(host='0.0.0.0', port=5000)"
# Out:
#  * Serving Flask app 'app'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.28.0.12:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [23/Sep/2026 17:45:35] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Sep/2026 17:45:36] "GET /static/js/app.js HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Sep/2026 17:45:36] "GET /static/css/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Sep/2026 17:45:37] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [23/Sep/2026 17:45:37] "GET /api/graph HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Sep/2026 17:45:46] "POST /api/predict HTTP/1.1" 200 -
